# %% [markdown]
# Basado en el artículo de Antal

# %%
import networkx as nx
import random

def inicializar_red(num_nodos):
    """
    Crea una red completa (todos los nodos conectados a todos los demás)
    y asigna aleatoriamente relaciones de amistad (+1) o enemistad (-1)
    a cada enlace.

    Args:
        num_nodos (int): El número de nodos en la red.

    Returns:
        nx.Graph: La red inicializada.
    """
    red = nx.Graph()
    red.add_nodes_from(range(num_nodos))

    for i in range(num_nodos):
        for j in range(i + 1, num_nodos):
            # Asigna aleatoriamente +1 (amigo) o -1 (enemigo)
            relacion = random.choice([1, -1])
            red.add_edge(i, j, relacion=relacion)
    return red

def obtener_relacion(red, nodo1, nodo2):
    """
    Obtiene la relación (amistad o enemistad) entre dos nodos.

    Args:
        red (nx.Graph): La red.
        nodo1 (int): El primer nodo.
        nodo2 (int): El segundo nodo.

    Returns:
        int: 1 si son amigos, -1 si son enemigos.
    """
    return red[nodo1][nodo2]['relacion']

def es_triada_balanceada(red, nodo1, nodo2, nodo3):
    """
    Verifica si una tríada (tres nodos conectados entre sí) está balanceada.
    Una tríada está balanceada si el producto de las relaciones entre sus nodos es +1.

    Args:
        red (nx.Graph): La red.
        nodo1 (int): El primer nodo de la tríada.
        nodo2 (int): El segundo nodo de la tríada.
        nodo3 (int): El tercer nodo de la tríada.

    Returns:
        bool: True si la tríada está balanceada, False de lo contrario.
    """
    relacion12 = obtener_relacion(red, nodo1, nodo2)
    relacion13 = obtener_relacion(red, nodo1, nodo3)
    relacion23 = obtener_relacion(red, nodo2, nodo3)

    producto_relaciones = relacion12 * relacion13 * relacion23
    return producto_relaciones == 1

def encontrar_triada_no_balanceada(red):
    """
    Busca una tríada no balanceada en la red.

    Args:
        red (nx.Graph): La red.

    Returns:
        tuple or None: Una tupla de tres nodos que forman una tríada no balanceada,
                       o None si no se encuentra ninguna.
    """
    nodos = list(red.nodes())
    for i in range(len(nodos)):
        for j in range(i + 1, len(nodos)):
            for k in range(j + 1, len(nodos)):
                if red.has_edge(nodos[i], nodos[j]) and \
                   red.has_edge(nodos[i], nodos[k]) and \
                   red.has_edge(nodos[j], nodos[k]):
                    if not es_triada_balanceada(red, nodos[i], nodos[j], nodos[k]):
                        return nodos[i], nodos[j], nodos[k]
    return None

def aplicar_dinamica(red, nodo1, nodo2, nodo3):
    """
    Aplica la dinámica de balance a una tríada no balanceada.
    Cambia la relación entre dos nodos de la tríada para balancearla.
    Se elige aleatoriamente un par de nodos de la tríada y se ajusta su relación.

    Args:
        red (nx.Graph): La red.
        nodo1 (int): El primer nodo de la tríada no balanceada.
        nodo2 (int): El segundo nodo de la tríada no balanceada.
        nodo3 (int): El tercer nodo de la tríada no balanceada.
    """
    pares_nodos = [(nodo1, nodo2), (nodo1, nodo3), (nodo2, nodo3)]
    n1, n2 = random.choice(pares_nodos)

    relacion_actual = obtener_relacion(red, n1, n2)

    # Para balancear la tríada, la nueva relación debe ser el producto de las otras dos
    otro_nodo = list(set([nodo1, nodo2, nodo3]) - set([n1, n2]))[0]
    nueva_relacion = obtener_relacion(red, n1, otro_nodo) * obtener_relacion(red, n2, otro_nodo)

    # Actualiza la relación en la red
    red[n1][n2]['relacion'] = nueva_relacion
    print(f"Se cambió la relación entre {n1} y {n2} a {'amigos' if nueva_relacion == 1 else 'enemigos'}.")

def simular_equilibrio(num_nodos, max_iteraciones=1000):
    """
    Simula la dinámica de balance en la red hasta alcanzar un equilibrio
    o un número máximo de iteraciones.

    Args:
        num_nodos (int): El número de nodos en la red.
        max_iteraciones (int): El número máximo de iteraciones a realizar.

    Returns:
        nx.Graph: La red en estado de equilibrio (o después del máximo de iteraciones).
    """
    red = inicializar_red(num_nodos)
    iteracion = 0
    while iteracion < max_iteraciones:
        triada_no_balanceada = encontrar_triada_no_balanceada(red)
        if triada_no_balanceada:
            print(f"Iteración {iteracion}: Se encontró una tríada no balanceada: {triada_no_balanceada}")
            aplicar_dinamica(red, *triada_no_balanceada)
        else:
            print(f"Se alcanzó el equilibrio en la iteración {iteracion}.")
            break
        iteracion += 1
    else:
        print(f"No se alcanzó el equilibrio después de {max_iteraciones} iteraciones.")
    return red

# Parámetros de la simulación
num_nodos = 6
red_equilibrada = simular_equilibrio(num_nodos)

# Imprimir las relaciones finales en la red equilibrada
print("\nRelaciones finales en la red equilibrada:")
for u, v, data in red_equilibrada.edges(data=True):
    relacion = "amigos" if data['relacion'] == 1 else "enemigos"
    print(f"Nodo {u} y Nodo {v}: {relacion}")

# Verificar si la red final está completamente balanceada
def esta_red_balanceada(red):
    nodos = list(red.nodes())
    for i in range(len(nodos)):
        for j in range(i + 1, len(nodos)):
            for k in range(j + 1, len(nodos)):
                if red.has_edge(nodos[i], nodos[j]) and \
                   red.has_edge(nodos[i], nodos[k]) and \
                   red.has_edge(nodos[j], nodos[k]):
                    if not es_triada_balanceada(red, nodos[i], nodos[j], nodos[k]):
                        return False
    return True

if esta_red_balanceada(red_equilibrada):
    print("\nLa red final está completamente balanceada.")
else:
    print("\nLa red final NO está completamente balanceada (después del máximo de iteraciones).")
# Out:
# Iteración 0: Se encontró una tríada no balanceada: (0, 2, 3)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 1: Se encontró una tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 2: Se encontró una tríada no balanceada: (0, 2, 3)
# Se cambió la relación entre 2 y 3 a enemigos.
# Iteración 3: Se encontró una tríada no balanceada: (0, 3, 5)
# Se cambió la relación entre 3 y 5 a amigos.
# Se alcanzó el equilibrio en la iteración 4.
#
# Relaciones finales en la red equilibrada:
# Nodo 0 y Nodo 1: amigos
# Nodo 0 y Nodo 2: enemigos
# Nodo 0 y Nodo 3: amigos
# Nodo 0 y Nodo 4: amigos
# Nodo 0 y Nodo 5: amigos
# Nodo 1 y Nodo 2: enemigos
# Nodo 1 y Nodo 3: amigos
# Nodo 1 y Nodo 4: amigos
# Nodo 1 y Nodo 5: amigos
# Nodo 2 y Nodo 3: enemigos
# Nodo 2 y Nodo 4: enemigos
# Nodo 2 y Nodo 5: enemigos
# Nodo 3 y Nodo 4: amigos
# Nodo 3 y Nodo 5: amigos
# Nodo 4 y Nodo 5: amigos
#
# La red final está completamente balanceada.

# %% [markdown]
# Se añade la visualización de la red final para observar las relaciones entre los nodos.

# %%
pip install pyvis
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyvis
#   Obtaining dependency information for pyvis from https://files.pythonhosted.org/packages/ab/4b/e37e4e5d5ee1179694917b445768bdbfb084f5a59ecd38089d3413d4c70f/pyvis-0.3.2-py3-none-any.whl.metadata
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: ipython>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from pyvis) (8.15.0)
# Requirement already satisfied: jinja2>=2.9.6 in c:\programdata\anaconda3\lib\site-packages (from pyvis) (3.1.2)
# Collecting jsonpickle>=1.4.1 (from pyvis)
#   Obtaining dependency information for jsonpickle>=1.4.1 from https://files.pythonhosted.org/packages/86/7c/c06580145924f60342f669f6e71905f838083d00e4b141172a75d22a23fc/jsonpickle-4.0.1-py3-none-any.whl.metadata
#   Downloading jsonpickle-4.0.1-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: networkx>=1.11 in c:\programdata\anaconda3\lib\site-packages (from pyvis) (3.1)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (2.15.1)
# Requirement already satisfied: stack-data in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (5.7.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9.6->pyvis) (2.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->pyvis) (0.2.5)
# Requirement already satisfied: executing in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: asttokens in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.0.5)
# Requirement already satisfied: pure-eval in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from asttokens->stack-data->ipython>=5.3.0->pyvis) (1.16.0)
# Using cached pyvis-0.3.2-py3-none-any.whl (756 kB)
# Downloading jsonpickle-4.0.1-py3-none-any.whl (46 kB)
#    ---------------------------------------- 0.0/46.2 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/46.2 kB ? eta -:--:--
#    ----------------- ---------------------- 20.5/46.2 kB 330.3 kB/s eta 0:00:01
#    ----------------------------------- ---- 41.0/46.2 kB 326.8 kB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 kB 327.3 kB/s eta 0:00:00
# Installing collected packages: jsonpickle, pyvis
# Successfully installed jsonpickle-4.0.1 pyvis-0.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx
import random
from pyvis.network import Network
import networkx as nx
import random
import json

def inicializar_red(num_nodos):
    """
    Crea una red completa y asigna relaciones aleatorias.
    """
    red = nx.Graph()
    red.add_nodes_from(range(num_nodos))
    for i in range(num_nodos):
        for j in range(i + 1, num_nodos):
            relacion = random.choice([1, -1])
            red.add_edge(i, j, relacion=relacion)
    return red

def obtener_relacion(red, nodo1, nodo2):
    return red[nodo1][nodo2]['relacion']

def es_triada_balanceada(red, nodo1, nodo2, nodo3):
    relacion12 = obtener_relacion(red, nodo1, nodo2)
    relacion13 = obtener_relacion(red, nodo1, nodo3)
    relacion23 = obtener_relacion(red, nodo2, nodo3)
    return relacion12 * relacion13 * relacion23 == 1

def encontrar_triada_no_balanceada(red):
    nodos = list(red.nodes())
    for i in range(len(nodos)):
        for j in range(i + 1, len(nodos)):
            for k in range(j + 1, len(nodos)):
                if red.has_edge(nodos[i], nodos[j]) and \
                   red.has_edge(nodos[i], nodos[k]) and \
                   red.has_edge(nodos[j], nodos[k]):
                    if not es_triada_balanceada(red, nodos[i], nodos[j], nodos[k]):
                        return nodos[i], nodos[j], nodos[k]
    return None

def aplicar_dinamica(red, nodo1, nodo2, nodo3):
    pares_nodos = [(nodo1, nodo2), (nodo1, nodo3), (nodo2, nodo3)]
    n1, n2 = random.choice(pares_nodos)
    otro_nodo = list(set([nodo1, nodo2, nodo3]) - set([n1, n2]))[0]
    nueva_relacion = obtener_relacion(red, n1, otro_nodo) * obtener_relacion(red, n2, otro_nodo)
    red[n1][n2]['relacion'] = nueva_relacion
    print(f"Se cambió la relación entre {n1} y {n2} a {'amigos' if nueva_relacion == 1 else 'enemigos'}.")

def simular_equilibrio(num_nodos, max_iteraciones=1000):
    red = inicializar_red(num_nodos)
    iteracion = 0
    while iteracion < max_iteraciones:
        triada_no_balanceada = encontrar_triada_no_balanceada(red)
        if triada_no_balanceada:
            print(f"Iteración {iteracion}: Tríada no balanceada: {triada_no_balanceada}")
            aplicar_dinamica(red, *triada_no_balanceada)
        else:
            print(f"Equilibrio alcanzado en la iteración {iteracion}.")
            break
        iteracion += 1
    else:
        print(f"No se alcanzó el equilibrio tras {max_iteraciones} iteraciones.")
    return red

def visualizar_red(red, filename="red_social.html"):
    """
    Visualiza la red utilizando pyvis con ajustes de física para mayor estabilidad.

    Args:
        red (nx.Graph): La red a visualizar.
        filename (str): El nombre del archivo HTML para guardar la visualización.
    """
    net = Network(notebook=True, height='100vh', width="100%", select_menu=True, filter_menu=True)

    # Configuración de la física para estabilizar la red
    net.barnes_hut() # Utiliza el algoritmo Barnes-Hut para mejor rendimiento en grafos grandes
    net.show_buttons() # Muestra los botones de física para control interactivo



    for node in red.nodes():
        net.add_node(node, label=str(node))

    for u, v, data in red.edges(data=True):
        color = "blue" if data['relacion'] == 1 else "red"
        weight = 1
        net.add_edge(u, v, color=color, weight=weight)

    net.show(filename, notebook=False)
    print(f"La red se ha visualizado y guardado en '{filename}'")

# Parámetros de la simulación
num_nodos = 50
red_equilibrada = simular_equilibrio(num_nodos)

# Imprimir las relaciones finales
print("\nRelaciones finales:")
for u, v, data in red_equilibrada.edges(data=True):
    relacion = "amigos" if data['relacion'] == 1 else "enemigos"
    print(f"Nodo {u} y Nodo {v}: {relacion}")

# Visualizar la red equilibrada
visualizar_red(red_equilibrada)
# Out:
# Iteración 0: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 1: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a amigos.
# Iteración 2: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 7 a amigos.
# Iteración 3: Tríada no balanceada: (0, 1, 13)
# Se cambió la relación entre 1 y 13 a amigos.
# Iteración 4: Tríada no balanceada: (0, 1, 14)
# Se cambió la relación entre 0 y 14 a amigos.
# Iteración 5: Tríada no balanceada: (0, 1, 15)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 6: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 7: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 1 y 3 a enemigos.
# Iteración 8: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 9: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 10: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 1 y 3 a amigos.
# Iteración 11: Tríada no balanceada: (0, 1, 15)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 12: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 13: Tríada no balanceada: (0, 1, 15)
# Se cambió la relación entre 0 y 15 a amigos.
# Iteración 14: Tríada no balanceada: (0, 1, 16)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 15: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 16: Tríada no balanceada: (0, 1, 16)
# Se cambió la relación entre 1 y 16 a enemigos.
# Iteración 17: Tríada no balanceada: (0, 1, 17)
# Se cambió la relación entre 1 y 17 a amigos.
# Iteración 18: Tríada no balanceada: (0, 1, 18)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 19: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 20: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 21: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 22: Tríada no balanceada: (0, 1, 18)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 23: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 24: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 25: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 26: Tríada no balanceada: (0, 1, 18)
# Se cambió la relación entre 1 y 18 a enemigos.
# Iteración 27: Tríada no balanceada: (0, 1, 19)
# Se cambió la relación entre 1 y 19 a enemigos.
# Iteración 28: Tríada no balanceada: (0, 1, 20)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 29: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 30: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 31: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 32: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 33: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 34: Tríada no balanceada: (0, 1, 20)
# Se cambió la relación entre 1 y 20 a amigos.
# Iteración 35: Tríada no balanceada: (0, 1, 22)
# Se cambió la relación entre 0 y 22 a enemigos.
# Iteración 36: Tríada no balanceada: (0, 1, 25)
# Se cambió la relación entre 0 y 25 a enemigos.
# Iteración 37: Tríada no balanceada: (0, 1, 27)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 38: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 39: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 40: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a enemigos.
# Iteración 41: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a enemigos.
# Iteración 42: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 43: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 44: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 1 y 6 a amigos.
# Iteración 45: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 46: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 47: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 48: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 49: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 1 y 3 a enemigos.
# Iteración 50: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 51: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 52: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 53: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 54: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a amigos.
# Iteración 55: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 5 a amigos.
# Iteración 56: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 57: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 58: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 1 y 6 a enemigos.
# Iteración 59: Tríada no balanceada: (0, 1, 27)
# Se cambió la relación entre 0 y 27 a amigos.
# Iteración 60: Tríada no balanceada: (0, 1, 29)
# Se cambió la relación entre 1 y 29 a enemigos.
# Iteración 61: Tríada no balanceada: (0, 1, 31)
# Se cambió la relación entre 1 y 31 a enemigos.
# Iteración 62: Tríada no balanceada: (0, 1, 33)
# Se cambió la relación entre 0 y 33 a enemigos.
# Iteración 63: Tríada no balanceada: (0, 1, 34)
# Se cambió la relación entre 1 y 34 a enemigos.
# Iteración 64: Tríada no balanceada: (0, 1, 35)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 65: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 66: Tríada no balanceada: (0, 1, 35)
# Se cambió la relación entre 1 y 35 a enemigos.
# Iteración 67: Tríada no balanceada: (0, 1, 37)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 68: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 69: Tríada no balanceada: (0, 1, 37)
# Se cambió la relación entre 1 y 37 a amigos.
# Iteración 70: Tríada no balanceada: (0, 1, 38)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 71: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 72: Tríada no balanceada: (0, 1, 38)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 73: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 74: Tríada no balanceada: (0, 1, 38)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 75: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 76: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 77: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 78: Tríada no balanceada: (0, 1, 38)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 79: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 80: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 81: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 82: Tríada no balanceada: (0, 1, 38)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 83: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 84: Tríada no balanceada: (0, 1, 38)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 85: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 86: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 87: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 88: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 89: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 90: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 91: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 92: Tríada no balanceada: (0, 1, 38)
# Se cambió la relación entre 0 y 38 a enemigos.
# Iteración 93: Tríada no balanceada: (0, 1, 39)
# Se cambió la relación entre 1 y 39 a amigos.
# Iteración 94: Tríada no balanceada: (0, 1, 40)
# Se cambió la relación entre 0 y 40 a enemigos.
# Iteración 95: Tríada no balanceada: (0, 1, 44)
# Se cambió la relación entre 0 y 44 a amigos.
# Iteración 96: Tríada no balanceada: (0, 1, 46)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 97: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 98: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 1 y 3 a amigos.
# Iteración 99: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a amigos.
# Iteración 100: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a amigos.
# Iteración 101: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 6 a enemigos.
# Iteración 102: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 1 y 7 a amigos.
# Iteración 103: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 1 y 8 a enemigos.
# Iteración 104: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 1 y 9 a amigos.
# Iteración 105: Tríada no balanceada: (0, 1, 10)
# Se cambió la relación entre 1 y 10 a enemigos.
# Iteración 106: Tríada no balanceada: (0, 1, 11)
# Se cambió la relación entre 0 y 11 a amigos.
# Iteración 107: Tríada no balanceada: (0, 1, 12)
# Se cambió la relación entre 1 y 12 a amigos.
# Iteración 108: Tríada no balanceada: (0, 1, 13)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 109: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 110: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 1 y 3 a enemigos.
# Iteración 111: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a enemigos.
# Iteración 112: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a enemigos.
# Iteración 113: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 1 y 6 a amigos.
# Iteración 114: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 1 y 7 a enemigos.
# Iteración 115: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 0 y 8 a amigos.
# Iteración 116: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 1 y 9 a enemigos.
# Iteración 117: Tríada no balanceada: (0, 1, 10)
# Se cambió la relación entre 1 y 10 a amigos.
# Iteración 118: Tríada no balanceada: (0, 1, 11)
# Se cambió la relación entre 0 y 11 a enemigos.
# Iteración 119: Tríada no balanceada: (0, 1, 12)
# Se cambió la relación entre 1 y 12 a enemigos.
# Iteración 120: Tríada no balanceada: (0, 1, 46)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 121: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 122: Tríada no balanceada: (0, 1, 46)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 123: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 124: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 125: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a enemigos.
# Iteración 126: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a amigos.
# Iteración 127: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 128: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 129: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 130: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 131: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 1 y 6 a enemigos.
# Iteración 132: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 133: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 134: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 135: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 136: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 137: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 138: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 139: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 140: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 141: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 142: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 143: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 144: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 145: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 146: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 147: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 148: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 149: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 150: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 151: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 152: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 153: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 154: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 155: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 156: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 157: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a amigos.
# Iteración 158: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 5 a enemigos.
# Iteración 159: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 1 y 6 a amigos.
# Iteración 160: Tríada no balanceada: (0, 1, 46)
# Se cambió la relación entre 1 y 46 a enemigos.
# Iteración 161: Tríada no balanceada: (0, 1, 47)
# Se cambió la relación entre 0 y 47 a amigos.
# Iteración 162: Tríada no balanceada: (0, 1, 49)
# Se cambió la relación entre 1 y 49 a amigos.
# Iteración 163: Tríada no balanceada: (0, 2, 4)
# Se cambió la relación entre 0 y 4 a amigos.
# Iteración 164: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 165: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 166: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 167: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 168: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 169: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 5 a amigos.
# Iteración 170: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 6 a amigos.
# Iteración 171: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 172: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 173: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 1 y 7 a amigos.
# Iteración 174: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 1 y 8 a amigos.
# Iteración 175: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 1 y 9 a amigos.
# Iteración 176: Tríada no balanceada: (0, 1, 10)
# Se cambió la relación entre 1 y 10 a enemigos.
# Iteración 177: Tríada no balanceada: (0, 1, 11)
# Se cambió la relación entre 0 y 11 a amigos.
# Iteración 178: Tríada no balanceada: (0, 1, 12)
# Se cambió la relación entre 0 y 12 a enemigos.
# Iteración 179: Tríada no balanceada: (0, 1, 13)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 180: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 181: Tríada no balanceada: (0, 1, 13)
# Se cambió la relación entre 1 y 13 a enemigos.
# Iteración 182: Tríada no balanceada: (0, 1, 14)
# Se cambió la relación entre 0 y 14 a enemigos.
# Iteración 183: Tríada no balanceada: (0, 1, 15)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 184: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 185: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 186: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 187: Tríada no balanceada: (0, 1, 15)
# Se cambió la relación entre 0 y 15 a enemigos.
# Iteración 188: Tríada no balanceada: (0, 1, 16)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 189: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 190: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 191: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 192: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 193: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 194: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 195: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 196: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 197: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a enemigos.
# Iteración 198: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 199: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 200: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 201: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 202: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 203: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 204: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a enemigos.
# Iteración 205: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 206: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 207: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 208: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 209: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 6 a enemigos.
# Iteración 210: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 211: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 212: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 213: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 214: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 1 y 3 a amigos.
# Iteración 215: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a enemigos.
# Iteración 216: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 217: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 218: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 219: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a amigos.
# Iteración 220: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 221: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 222: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 223: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 224: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 225: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 226: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 1 y 3 a enemigos.
# Iteración 227: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a enemigos.
# Iteración 228: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 229: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 230: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a amigos.
# Iteración 231: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 1 y 6 a enemigos.
# Iteración 232: Tríada no balanceada: (0, 1, 16)
# Se cambió la relación entre 1 y 16 a amigos.
# Iteración 233: Tríada no balanceada: (0, 1, 17)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 234: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 235: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 1 y 3 a amigos.
# Iteración 236: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a amigos.
# Iteración 237: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 238: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 239: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 240: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 241: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 242: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 243: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a enemigos.
# Iteración 244: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 245: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 246: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 247: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 248: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 1 y 6 a amigos.
# Iteración 249: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 1 y 7 a enemigos.
# Iteración 250: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 1 y 8 a enemigos.
# Iteración 251: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 0 y 9 a enemigos.
# Iteración 252: Tríada no balanceada: (0, 1, 10)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 253: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 254: Tríada no balanceada: (0, 1, 10)
# Se cambió la relación entre 1 y 10 a amigos.
# Iteración 255: Tríada no balanceada: (0, 1, 11)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 256: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 257: Tríada no balanceada: (0, 1, 11)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 258: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 259: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 260: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a amigos.
# Iteración 261: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a amigos.
# Iteración 262: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 6 a amigos.
# Iteración 263: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 264: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 265: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 7 a enemigos.
# Iteración 266: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 0 y 8 a enemigos.
# Iteración 267: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 1 y 9 a enemigos.
# Iteración 268: Tríada no balanceada: (0, 1, 10)
# Se cambió la relación entre 1 y 10 a enemigos.
# Iteración 269: Tríada no balanceada: (0, 1, 17)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 270: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 271: Tríada no balanceada: (0, 1, 17)
# Se cambió la relación entre 0 y 17 a amigos.
# Iteración 272: Tríada no balanceada: (0, 1, 18)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 273: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 274: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 275: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 276: Tríada no balanceada: (0, 1, 18)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 277: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 278: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 1 y 3 a enemigos.
# Iteración 279: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a enemigos.
# Iteración 280: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 281: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 282: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 5 a enemigos.
# Iteración 283: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 284: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 285: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 286: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a enemigos.
# Iteración 287: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 288: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 289: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 290: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a amigos.
# Iteración 291: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 6 a enemigos.
# Iteración 292: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 7 a amigos.
# Iteración 293: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 1 y 8 a amigos.
# Iteración 294: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 295: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 296: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 297: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 298: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 299: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a amigos.
# Iteración 300: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 5 a amigos.
# Iteración 301: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 302: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 303: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 6 a amigos.
# Iteración 304: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 305: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 306: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 307: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a enemigos.
# Iteración 308: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 309: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 310: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a enemigos.
# Iteración 311: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 312: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 313: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 314: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 315: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 316: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 317: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 6 a enemigos.
# Iteración 318: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 0 y 9 a amigos.
# Iteración 319: Tríada no balanceada: (0, 1, 10)
# Se cambió la relación entre 0 y 10 a amigos.
# Iteración 320: Tríada no balanceada: (0, 1, 11)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 321: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 322: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 323: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a amigos.
# Iteración 324: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 325: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 326: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 5 a enemigos.
# Iteración 327: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 328: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 329: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 330: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 331: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 332: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 333: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 1 y 6 a enemigos.
# Iteración 334: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 7 a enemigos.
# Iteración 335: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 1 y 8 a enemigos.
# Iteración 336: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 0 y 9 a enemigos.
# Iteración 337: Tríada no balanceada: (0, 1, 10)
# Se cambió la relación entre 0 y 10 a enemigos.
# Iteración 338: Tríada no balanceada: (0, 1, 18)
# Se cambió la relación entre 0 y 18 a enemigos.
# Iteración 339: Tríada no balanceada: (0, 1, 19)
# Se cambió la relación entre 0 y 19 a enemigos.
# Iteración 340: Tríada no balanceada: (0, 1, 20)
# Se cambió la relación entre 0 y 20 a amigos.
# Iteración 341: Tríada no balanceada: (0, 1, 21)
# Se cambió la relación entre 1 y 21 a amigos.
# Iteración 342: Tríada no balanceada: (0, 1, 22)
# Se cambió la relación entre 1 y 22 a enemigos.
# Iteración 343: Tríada no balanceada: (0, 1, 23)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 344: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 345: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 346: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a enemigos.
# Iteración 347: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a amigos.
# Iteración 348: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 6 a amigos.
# Iteración 349: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 1 y 7 a amigos.
# Iteración 350: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 1 y 8 a amigos.
# Iteración 351: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 352: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 353: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 354: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 355: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 356: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 357: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 358: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a amigos.
# Iteración 359: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a enemigos.
# Iteración 360: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 6 a enemigos.
# Iteración 361: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 1 y 7 a enemigos.
# Iteración 362: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 1 y 8 a enemigos.
# Iteración 363: Tríada no balanceada: (0, 1, 23)
# Se cambió la relación entre 0 y 23 a amigos.
# Iteración 364: Tríada no balanceada: (0, 1, 24)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 365: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 366: Tríada no balanceada: (0, 1, 24)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 367: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 368: Tríada no balanceada: (0, 1, 24)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 369: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 370: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 371: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 372: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 373: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a enemigos.
# Iteración 374: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a amigos.
# Iteración 375: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 6 a amigos.
# Iteración 376: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 7 a amigos.
# Iteración 377: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 378: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 379: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 0 y 8 a amigos.
# Iteración 380: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 0 y 9 a amigos.
# Iteración 381: Tríada no balanceada: (0, 1, 10)
# Se cambió la relación entre 0 y 10 a amigos.
# Iteración 382: Tríada no balanceada: (0, 1, 11)
# Se cambió la relación entre 1 y 11 a enemigos.
# Iteración 383: Tríada no balanceada: (0, 1, 12)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 384: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 385: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 1 y 3 a amigos.
# Iteración 386: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a amigos.
# Iteración 387: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a enemigos.
# Iteración 388: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 6 a enemigos.
# Iteración 389: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 1 y 7 a amigos.
# Iteración 390: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 1 y 8 a amigos.
# Iteración 391: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 1 y 9 a amigos.
# Iteración 392: Tríada no balanceada: (0, 1, 10)
# Se cambió la relación entre 0 y 10 a enemigos.
# Iteración 393: Tríada no balanceada: (0, 1, 11)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 394: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 395: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 1 y 3 a enemigos.
# Iteración 396: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a enemigos.
# Iteración 397: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 5 a amigos.
# Iteración 398: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 399: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 400: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 401: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 402: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 6 a amigos.
# Iteración 403: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 404: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 405: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 406: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a enemigos.
# Iteración 407: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a amigos.
# Iteración 408: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 409: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 410: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 411: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 412: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 413: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 414: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 415: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 416: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 1 y 6 a amigos.
# Iteración 417: Tríada no balanceada: (0, 1, 11)
# Se cambió la relación entre 1 y 11 a amigos.
# Iteración 418: Tríada no balanceada: (0, 1, 24)
# Se cambió la relación entre 0 y 24 a amigos.
# Iteración 419: Tríada no balanceada: (0, 1, 25)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 420: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 421: Tríada no balanceada: (0, 1, 25)
# Se cambió la relación entre 0 y 25 a amigos.
# Iteración 422: Tríada no balanceada: (0, 1, 26)
# Se cambió la relación entre 0 y 26 a amigos.
# Iteración 423: Tríada no balanceada: (0, 1, 27)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 424: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 425: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 426: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a amigos.
# Iteración 427: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 5 a enemigos.
# Iteración 428: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 1 y 6 a enemigos.
# Iteración 429: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 430: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 431: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 7 a enemigos.
# Iteración 432: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 0 y 8 a enemigos.
# Iteración 433: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 434: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 435: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 436: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 437: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 438: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 439: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 440: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a enemigos.
# Iteración 441: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 442: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 443: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 444: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 445: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 446: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 447: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a enemigos.
# Iteración 448: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 1 y 6 a amigos.
# Iteración 449: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 450: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 451: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 7 a amigos.
# Iteración 452: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 1 y 8 a enemigos.
# Iteración 453: Tríada no balanceada: (0, 1, 27)
# Se cambió la relación entre 0 y 27 a enemigos.
# Iteración 454: Tríada no balanceada: (0, 1, 28)
# Se cambió la relación entre 0 y 28 a amigos.
# Iteración 455: Tríada no balanceada: (0, 1, 29)
# Se cambió la relación entre 1 y 29 a amigos.
# Iteración 456: Tríada no balanceada: (0, 1, 30)
# Se cambió la relación entre 0 y 30 a enemigos.
# Iteración 457: Tríada no balanceada: (0, 1, 31)
# Se cambió la relación entre 0 y 31 a enemigos.
# Iteración 458: Tríada no balanceada: (0, 1, 32)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 459: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 460: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 461: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a amigos.
# Iteración 462: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 5 a amigos.
# Iteración 463: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 1 y 6 a enemigos.
# Iteración 464: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 7 a enemigos.
# Iteración 465: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 466: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 467: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 468: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 469: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 470: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 471: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 1 y 8 a amigos.
# Iteración 472: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 1 y 9 a enemigos.
# Iteración 473: Tríada no balanceada: (0, 1, 10)
# Se cambió la relación entre 0 y 10 a amigos.
# Iteración 474: Tríada no balanceada: (0, 1, 11)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 475: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 476: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 477: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a enemigos.
# Iteración 478: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 479: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 480: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 481: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a amigos.
# Iteración 482: Tríada no balanceada: (0, 1, 11)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 483: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 484: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 485: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 486: Tríada no balanceada: (0, 1, 11)
# Se cambió la relación entre 1 y 11 a enemigos.
# Iteración 487: Tríada no balanceada: (0, 1, 12)
# Se cambió la relación entre 1 y 12 a amigos.
# Iteración 488: Tríada no balanceada: (0, 1, 13)
# Se cambió la relación entre 1 y 13 a amigos.
# Iteración 489: Tríada no balanceada: (0, 1, 14)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 490: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 491: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 492: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 493: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 1 y 3 a amigos.
# Iteración 494: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 495: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 496: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 497: Tríada no balanceada: (0, 1, 14)
# Se cambió la relación entre 1 y 14 a amigos.
# Iteración 498: Tríada no balanceada: (0, 1, 15)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 499: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 500: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 501: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 502: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 503: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 504: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 505: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 506: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 507: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a amigos.
# Iteración 508: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 5 a enemigos.
# Iteración 509: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 510: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 511: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 512: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a enemigos.
# Iteración 513: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 514: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 515: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 516: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 517: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 518: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a amigos.
# Iteración 519: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 520: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# ...
# Nodo 15 y Nodo 30: amigos
# Nodo 15 y Nodo 31: amigos
# Nodo 15 y Nodo 32: amigos
# Nodo 15 y Nodo 33: amigos
# Nodo 15 y Nodo 34: enemigos
# Nodo 15 y Nodo 35: enemigos
# Nodo 15 y Nodo 36: amigos
# Nodo 15 y Nodo 37: enemigos
# Nodo 15 y Nodo 38: enemigos
# Nodo 15 y Nodo 39: enemigos
# Nodo 15 y Nodo 40: amigos
# Nodo 15 y Nodo 41: enemigos
# Nodo 15 y Nodo 42: amigos
# Nodo 15 y Nodo 43: enemigos
# Nodo 15 y Nodo 44: amigos
# Nodo 15 y Nodo 45: enemigos
# Nodo 15 y Nodo 46: amigos
# Nodo 15 y Nodo 47: amigos
# Nodo 15 y Nodo 48: amigos
# Nodo 15 y Nodo 49: amigos
# Nodo 16 y Nodo 17: enemigos
# Nodo 16 y Nodo 18: enemigos
# Nodo 16 y Nodo 19: enemigos
# Nodo 16 y Nodo 20: amigos
# Nodo 16 y Nodo 21: amigos
# Nodo 16 y Nodo 22: enemigos
# Nodo 16 y Nodo 23: amigos
# Nodo 16 y Nodo 24: enemigos
# Nodo 16 y Nodo 25: amigos
# Nodo 16 y Nodo 26: enemigos
# Nodo 16 y Nodo 27: enemigos
# Nodo 16 y Nodo 28: enemigos
# Nodo 16 y Nodo 29: amigos
# Nodo 16 y Nodo 30: enemigos
# Nodo 16 y Nodo 31: amigos
# Nodo 16 y Nodo 32: enemigos
# Nodo 16 y Nodo 33: amigos
# Nodo 16 y Nodo 34: enemigos
# Nodo 16 y Nodo 35: enemigos
# Nodo 16 y Nodo 36: amigos
# Nodo 16 y Nodo 37: enemigos
# Nodo 16 y Nodo 38: enemigos
# Nodo 16 y Nodo 39: amigos
# Nodo 16 y Nodo 40: amigos
# Nodo 16 y Nodo 41: enemigos
# Nodo 16 y Nodo 42: amigos
# Nodo 16 y Nodo 43: amigos
# Nodo 16 y Nodo 44: enemigos
# Nodo 16 y Nodo 45: amigos
# Nodo 16 y Nodo 46: amigos
# Nodo 16 y Nodo 47: enemigos
# Nodo 16 y Nodo 48: enemigos
# Nodo 16 y Nodo 49: enemigos
# Nodo 17 y Nodo 18: enemigos
# Nodo 17 y Nodo 19: amigos
# Nodo 17 y Nodo 20: enemigos
# Nodo 17 y Nodo 21: amigos
# Nodo 17 y Nodo 22: amigos
# Nodo 17 y Nodo 23: enemigos
# Nodo 17 y Nodo 24: enemigos
# Nodo 17 y Nodo 25: amigos
# Nodo 17 y Nodo 26: enemigos
# Nodo 17 y Nodo 27: amigos
# Nodo 17 y Nodo 28: enemigos
# Nodo 17 y Nodo 29: amigos
# Nodo 17 y Nodo 30: amigos
# Nodo 17 y Nodo 31: enemigos
# Nodo 17 y Nodo 32: enemigos
# Nodo 17 y Nodo 33: enemigos
# Nodo 17 y Nodo 34: amigos
# Nodo 17 y Nodo 35: enemigos
# Nodo 17 y Nodo 36: enemigos
# Nodo 17 y Nodo 37: enemigos
# Nodo 17 y Nodo 38: enemigos
# Nodo 17 y Nodo 39: amigos
# Nodo 17 y Nodo 40: enemigos
# Nodo 17 y Nodo 41: amigos
# Nodo 17 y Nodo 42: amigos
# Nodo 17 y Nodo 43: amigos
# Nodo 17 y Nodo 44: amigos
# Nodo 17 y Nodo 45: amigos
# Nodo 17 y Nodo 46: amigos
# Nodo 17 y Nodo 47: amigos
# Nodo 17 y Nodo 48: enemigos
# Nodo 17 y Nodo 49: amigos
# Nodo 18 y Nodo 19: enemigos
# Nodo 18 y Nodo 20: amigos
# Nodo 18 y Nodo 21: enemigos
# Nodo 18 y Nodo 22: amigos
# Nodo 18 y Nodo 23: amigos
# Nodo 18 y Nodo 24: amigos
# Nodo 18 y Nodo 25: enemigos
# Nodo 18 y Nodo 26: enemigos
# Nodo 18 y Nodo 27: amigos
# Nodo 18 y Nodo 28: amigos
# Nodo 18 y Nodo 29: enemigos
# Nodo 18 y Nodo 30: amigos
# Nodo 18 y Nodo 31: enemigos
# Nodo 18 y Nodo 32: enemigos
# Nodo 18 y Nodo 33: enemigos
# Nodo 18 y Nodo 34: amigos
# Nodo 18 y Nodo 35: amigos
# Nodo 18 y Nodo 36: enemigos
# Nodo 18 y Nodo 37: amigos
# Nodo 18 y Nodo 38: amigos
# Nodo 18 y Nodo 39: amigos
# Nodo 18 y Nodo 40: enemigos
# Nodo 18 y Nodo 41: enemigos
# Nodo 18 y Nodo 42: enemigos
# Nodo 18 y Nodo 43: amigos
# Nodo 18 y Nodo 44: amigos
# Nodo 18 y Nodo 45: amigos
# Nodo 18 y Nodo 46: enemigos
# Nodo 18 y Nodo 47: enemigos
# Nodo 18 y Nodo 48: enemigos
# Nodo 18 y Nodo 49: enemigos
# Nodo 19 y Nodo 20: amigos
# Nodo 19 y Nodo 21: enemigos
# Nodo 19 y Nodo 22: enemigos
# Nodo 19 y Nodo 23: amigos
# Nodo 19 y Nodo 24: amigos
# Nodo 19 y Nodo 25: enemigos
# Nodo 19 y Nodo 26: enemigos
# Nodo 19 y Nodo 27: amigos
# Nodo 19 y Nodo 28: enemigos
# Nodo 19 y Nodo 29: amigos
# Nodo 19 y Nodo 30: amigos
# Nodo 19 y Nodo 31: amigos
# Nodo 19 y Nodo 32: enemigos
# Nodo 19 y Nodo 33: amigos
# Nodo 19 y Nodo 34: amigos
# Nodo 19 y Nodo 35: enemigos
# Nodo 19 y Nodo 36: enemigos
# Nodo 19 y Nodo 37: enemigos
# Nodo 19 y Nodo 38: amigos
# Nodo 19 y Nodo 39: enemigos
# Nodo 19 y Nodo 40: amigos
# Nodo 19 y Nodo 41: amigos
# Nodo 19 y Nodo 42: enemigos
# Nodo 19 y Nodo 43: enemigos
# Nodo 19 y Nodo 44: amigos
# Nodo 19 y Nodo 45: enemigos
# Nodo 19 y Nodo 46: enemigos
# Nodo 19 y Nodo 47: amigos
# Nodo 19 y Nodo 48: amigos
# Nodo 19 y Nodo 49: enemigos
# Nodo 20 y Nodo 21: enemigos
# Nodo 20 y Nodo 22: enemigos
# Nodo 20 y Nodo 23: enemigos
# Nodo 20 y Nodo 24: enemigos
# Nodo 20 y Nodo 25: enemigos
# Nodo 20 y Nodo 26: enemigos
# Nodo 20 y Nodo 27: amigos
# Nodo 20 y Nodo 28: amigos
# Nodo 20 y Nodo 29: enemigos
# Nodo 20 y Nodo 30: enemigos
# Nodo 20 y Nodo 31: amigos
# Nodo 20 y Nodo 32: enemigos
# Nodo 20 y Nodo 33: amigos
# Nodo 20 y Nodo 34: amigos
# Nodo 20 y Nodo 35: amigos
# Nodo 20 y Nodo 36: enemigos
# Nodo 20 y Nodo 37: amigos
# Nodo 20 y Nodo 38: amigos
# Nodo 20 y Nodo 39: enemigos
# Nodo 20 y Nodo 40: amigos
# Nodo 20 y Nodo 41: amigos
# Nodo 20 y Nodo 42: amigos
# Nodo 20 y Nodo 43: enemigos
# Nodo 20 y Nodo 44: amigos
# Nodo 20 y Nodo 45: enemigos
# Nodo 20 y Nodo 46: amigos
# Nodo 20 y Nodo 47: amigos
# Nodo 20 y Nodo 48: amigos
# Nodo 20 y Nodo 49: amigos
# Nodo 21 y Nodo 22: enemigos
# Nodo 21 y Nodo 23: enemigos
# Nodo 21 y Nodo 24: enemigos
# Nodo 21 y Nodo 25: enemigos
# Nodo 21 y Nodo 26: amigos
# Nodo 21 y Nodo 27: enemigos
# Nodo 21 y Nodo 28: amigos
# Nodo 21 y Nodo 29: enemigos
# Nodo 21 y Nodo 30: amigos
# Nodo 21 y Nodo 31: amigos
# Nodo 21 y Nodo 32: enemigos
# Nodo 21 y Nodo 33: enemigos
# Nodo 21 y Nodo 34: amigos
# Nodo 21 y Nodo 35: enemigos
# Nodo 21 y Nodo 36: amigos
# Nodo 21 y Nodo 37: amigos
# Nodo 21 y Nodo 38: amigos
# Nodo 21 y Nodo 39: enemigos
# Nodo 21 y Nodo 40: enemigos
# Nodo 21 y Nodo 41: amigos
# Nodo 21 y Nodo 42: enemigos
# Nodo 21 y Nodo 43: enemigos
# Nodo 21 y Nodo 44: amigos
# Nodo 21 y Nodo 45: enemigos
# Nodo 21 y Nodo 46: amigos
# Nodo 21 y Nodo 47: amigos
# Nodo 21 y Nodo 48: enemigos
# Nodo 21 y Nodo 49: amigos
# Nodo 22 y Nodo 23: enemigos
# Nodo 22 y Nodo 24: enemigos
# Nodo 22 y Nodo 25: enemigos
# Nodo 22 y Nodo 26: enemigos
# Nodo 22 y Nodo 27: amigos
# Nodo 22 y Nodo 28: enemigos
# Nodo 22 y Nodo 29: amigos
# Nodo 22 y Nodo 30: enemigos
# Nodo 22 y Nodo 31: amigos
# Nodo 22 y Nodo 32: enemigos
# Nodo 22 y Nodo 33: enemigos
# Nodo 22 y Nodo 34: amigos
# Nodo 22 y Nodo 35: amigos
# Nodo 22 y Nodo 36: enemigos
# Nodo 22 y Nodo 37: enemigos
# Nodo 22 y Nodo 38: amigos
# Nodo 22 y Nodo 39: enemigos
# Nodo 22 y Nodo 40: enemigos
# Nodo 22 y Nodo 41: enemigos
# Nodo 22 y Nodo 42: enemigos
# Nodo 22 y Nodo 43: amigos
# Nodo 22 y Nodo 44: enemigos
# Nodo 22 y Nodo 45: amigos
# Nodo 22 y Nodo 46: enemigos
# Nodo 22 y Nodo 47: amigos
# Nodo 22 y Nodo 48: amigos
# Nodo 22 y Nodo 49: enemigos
# Nodo 23 y Nodo 24: enemigos
# Nodo 23 y Nodo 25: enemigos
# Nodo 23 y Nodo 26: amigos
# Nodo 23 y Nodo 27: enemigos
# Nodo 23 y Nodo 28: amigos
# Nodo 23 y Nodo 29: amigos
# Nodo 23 y Nodo 30: enemigos
# Nodo 23 y Nodo 31: amigos
# Nodo 23 y Nodo 32: amigos
# Nodo 23 y Nodo 33: enemigos
# Nodo 23 y Nodo 34: amigos
# Nodo 23 y Nodo 35: amigos
# Nodo 23 y Nodo 36: enemigos
# Nodo 23 y Nodo 37: amigos
# Nodo 23 y Nodo 38: amigos
# Nodo 23 y Nodo 39: amigos
# Nodo 23 y Nodo 40: amigos
# Nodo 23 y Nodo 41: amigos
# Nodo 23 y Nodo 42: amigos
# Nodo 23 y Nodo 43: amigos
# Nodo 23 y Nodo 44: amigos
# Nodo 23 y Nodo 45: enemigos
# Nodo 23 y Nodo 46: amigos
# Nodo 23 y Nodo 47: enemigos
# Nodo 23 y Nodo 48: amigos
# Nodo 23 y Nodo 49: enemigos
# Nodo 24 y Nodo 25: enemigos
# Nodo 24 y Nodo 26: enemigos
# Nodo 24 y Nodo 27: amigos
# Nodo 24 y Nodo 28: enemigos
# Nodo 24 y Nodo 29: enemigos
# Nodo 24 y Nodo 30: amigos
# Nodo 24 y Nodo 31: enemigos
# Nodo 24 y Nodo 32: enemigos
# Nodo 24 y Nodo 33: amigos
# Nodo 24 y Nodo 34: amigos
# Nodo 24 y Nodo 35: amigos
# Nodo 24 y Nodo 36: enemigos
# Nodo 24 y Nodo 37: amigos
# Nodo 24 y Nodo 38: enemigos
# Nodo 24 y Nodo 39: enemigos
# Nodo 24 y Nodo 40: enemigos
# Nodo 24 y Nodo 41: enemigos
# Nodo 24 y Nodo 42: enemigos
# Nodo 24 y Nodo 43: enemigos
# Nodo 24 y Nodo 44: enemigos
# Nodo 24 y Nodo 45: amigos
# Nodo 24 y Nodo 46: enemigos
# Nodo 24 y Nodo 47: amigos
# Nodo 24 y Nodo 48: enemigos
# Nodo 24 y Nodo 49: enemigos
# Nodo 25 y Nodo 26: amigos
# Nodo 25 y Nodo 27: amigos
# Nodo 25 y Nodo 28: amigos
# Nodo 25 y Nodo 29: amigos
# Nodo 25 y Nodo 30: enemigos
# Nodo 25 y Nodo 31: amigos
# Nodo 25 y Nodo 32: amigos
# Nodo 25 y Nodo 33: amigos
# Nodo 25 y Nodo 34: amigos
# Nodo 25 y Nodo 35: enemigos
# Nodo 25 y Nodo 36: amigos
# Nodo 25 y Nodo 37: enemigos
# Nodo 25 y Nodo 38: enemigos
# Nodo 25 y Nodo 39: enemigos
# Nodo 25 y Nodo 40: amigos
# Nodo 25 y Nodo 41: enemigos
# Nodo 25 y Nodo 42: enemigos
# Nodo 25 y Nodo 43: amigos
# Nodo 25 y Nodo 44: enemigos
# Nodo 25 y Nodo 45: amigos
# Nodo 25 y Nodo 46: enemigos
# Nodo 25 y Nodo 47: enemigos
# Nodo 25 y Nodo 48: enemigos
# Nodo 25 y Nodo 49: amigos
# Nodo 26 y Nodo 27: amigos
# Nodo 26 y Nodo 28: amigos
# Nodo 26 y Nodo 29: enemigos
# Nodo 26 y Nodo 30: enemigos
# Nodo 26 y Nodo 31: amigos
# Nodo 26 y Nodo 32: amigos
# Nodo 26 y Nodo 33: enemigos
# Nodo 26 y Nodo 34: amigos
# Nodo 26 y Nodo 35: enemigos
# Nodo 26 y Nodo 36: enemigos
# Nodo 26 y Nodo 37: amigos
# Nodo 26 y Nodo 38: amigos
# Nodo 26 y Nodo 39: amigos
# Nodo 26 y Nodo 40: enemigos
# Nodo 26 y Nodo 41: amigos
# Nodo 26 y Nodo 42: enemigos
# Nodo 26 y Nodo 43: amigos
# Nodo 26 y Nodo 44: amigos
# Nodo 26 y Nodo 45: amigos
# Nodo 26 y Nodo 46: enemigos
# Nodo 26 y Nodo 47: amigos
# Nodo 26 y Nodo 48: enemigos
# Nodo 26 y Nodo 49: amigos
# Nodo 27 y Nodo 28: enemigos
# Nodo 27 y Nodo 29: enemigos
# Nodo 27 y Nodo 30: amigos
# Nodo 27 y Nodo 31: amigos
# Nodo 27 y Nodo 32: enemigos
# Nodo 27 y Nodo 33: amigos
# Nodo 27 y Nodo 34: enemigos
# Nodo 27 y Nodo 35: amigos
# Nodo 27 y Nodo 36: amigos
# Nodo 27 y Nodo 37: amigos
# Nodo 27 y Nodo 38: amigos
# Nodo 27 y Nodo 39: enemigos
# Nodo 27 y Nodo 40: amigos
# Nodo 27 y Nodo 41: enemigos
# Nodo 27 y Nodo 42: amigos
# Nodo 27 y Nodo 43: enemigos
# Nodo 27 y Nodo 44: amigos
# Nodo 27 y Nodo 45: amigos
# Nodo 27 y Nodo 46: enemigos
# Nodo 27 y Nodo 47: enemigos
# Nodo 27 y Nodo 48: amigos
# Nodo 27 y Nodo 49: enemigos
# Nodo 28 y Nodo 29: enemigos
# Nodo 28 y Nodo 30: amigos
# Nodo 28 y Nodo 31: amigos
# Nodo 28 y Nodo 32: amigos
# Nodo 28 y Nodo 33: enemigos
# Nodo 28 y Nodo 34: enemigos
# Nodo 28 y Nodo 35: amigos
# Nodo 28 y Nodo 36: enemigos
# Nodo 28 y Nodo 37: enemigos
# Nodo 28 y Nodo 38: amigos
# Nodo 28 y Nodo 39: amigos
# Nodo 28 y Nodo 40: enemigos
# Nodo 28 y Nodo 41: amigos
# Nodo 28 y Nodo 42: enemigos
# Nodo 28 y Nodo 43: enemigos
# Nodo 28 y Nodo 44: amigos
# Nodo 28 y Nodo 45: enemigos
# Nodo 28 y Nodo 46: enemigos
# Nodo 28 y Nodo 47: amigos
# Nodo 28 y Nodo 48: enemigos
# Nodo 28 y Nodo 49: amigos
# Nodo 29 y Nodo 30: amigos
# Nodo 29 y Nodo 31: amigos
# Nodo 29 y Nodo 32: amigos
# Nodo 29 y Nodo 33: enemigos
# Nodo 29 y Nodo 34: amigos
# Nodo 29 y Nodo 35: enemigos
# Nodo 29 y Nodo 36: amigos
# Nodo 29 y Nodo 37: amigos
# Nodo 29 y Nodo 38: enemigos
# Nodo 29 y Nodo 39: enemigos
# Nodo 29 y Nodo 40: enemigos
# Nodo 29 y Nodo 41: enemigos
# Nodo 29 y Nodo 42: enemigos
# Nodo 29 y Nodo 43: amigos
# Nodo 29 y Nodo 44: amigos
# Nodo 29 y Nodo 45: amigos
# Nodo 29 y Nodo 46: amigos
# Nodo 29 y Nodo 47: amigos
# Nodo 29 y Nodo 48: amigos
# Nodo 29 y Nodo 49: amigos
# Nodo 30 y Nodo 31: amigos
# Nodo 30 y Nodo 32: enemigos
# Nodo 30 y Nodo 33: enemigos
# Nodo 30 y Nodo 34: amigos
# Nodo 30 y Nodo 35: enemigos
# Nodo 30 y Nodo 36: enemigos
# Nodo 30 y Nodo 37: amigos
# Nodo 30 y Nodo 38: amigos
# Nodo 30 y Nodo 39: enemigos
# Nodo 30 y Nodo 40: amigos
# Nodo 30 y Nodo 41: enemigos
# Nodo 30 y Nodo 42: enemigos
# Nodo 30 y Nodo 43: amigos
# Nodo 30 y Nodo 44: amigos
# Nodo 30 y Nodo 45: amigos
# Nodo 30 y Nodo 46: enemigos
# Nodo 30 y Nodo 47: enemigos
# Nodo 30 y Nodo 48: amigos
# Nodo 30 y Nodo 49: enemigos
# Nodo 31 y Nodo 32: enemigos
# Nodo 31 y Nodo 33: amigos
# Nodo 31 y Nodo 34: enemigos
# Nodo 31 y Nodo 35: amigos
# Nodo 31 y Nodo 36: amigos
# Nodo 31 y Nodo 37: amigos
# Nodo 31 y Nodo 38: amigos
# Nodo 31 y Nodo 39: enemigos
# Nodo 31 y Nodo 40: amigos
# Nodo 31 y Nodo 41: enemigos
# Nodo 31 y Nodo 42: amigos
# Nodo 31 y Nodo 43: enemigos
# Nodo 31 y Nodo 44: enemigos
# Nodo 31 y Nodo 45: amigos
# Nodo 31 y Nodo 46: amigos
# Nodo 31 y Nodo 47: amigos
# Nodo 31 y Nodo 48: amigos
# Nodo 31 y Nodo 49: amigos
# Nodo 32 y Nodo 33: amigos
# Nodo 32 y Nodo 34: amigos
# Nodo 32 y Nodo 35: amigos
# Nodo 32 y Nodo 36: enemigos
# Nodo 32 y Nodo 37: amigos
# Nodo 32 y Nodo 38: enemigos
# Nodo 32 y Nodo 39: enemigos
# Nodo 32 y Nodo 40: enemigos
# Nodo 32 y Nodo 41: enemigos
# Nodo 32 y Nodo 42: amigos
# Nodo 32 y Nodo 43: amigos
# Nodo 32 y Nodo 44: amigos
# Nodo 32 y Nodo 45: amigos
# Nodo 32 y Nodo 46: enemigos
# Nodo 32 y Nodo 47: enemigos
# Nodo 32 y Nodo 48: enemigos
# Nodo 32 y Nodo 49: amigos
# Nodo 33 y Nodo 34: amigos
# Nodo 33 y Nodo 35: amigos
# Nodo 33 y Nodo 36: enemigos
# Nodo 33 y Nodo 37: enemigos
# Nodo 33 y Nodo 38: amigos
# Nodo 33 y Nodo 39: enemigos
# Nodo 33 y Nodo 40: enemigos
# Nodo 33 y Nodo 41: amigos
# Nodo 33 y Nodo 42: amigos
# Nodo 33 y Nodo 43: enemigos
# Nodo 33 y Nodo 44: enemigos
# Nodo 33 y Nodo 45: enemigos
# Nodo 33 y Nodo 46: enemigos
# Nodo 33 y Nodo 47: enemigos
# Nodo 33 y Nodo 48: enemigos
# Nodo 33 y Nodo 49: amigos
# Nodo 34 y Nodo 35: enemigos
# Nodo 34 y Nodo 36: amigos
# Nodo 34 y Nodo 37: amigos
# Nodo 34 y Nodo 38: enemigos
# Nodo 34 y Nodo 39: amigos
# Nodo 34 y Nodo 40: amigos
# Nodo 34 y Nodo 41: enemigos
# Nodo 34 y Nodo 42: amigos
# Nodo 34 y Nodo 43: amigos
# Nodo 34 y Nodo 44: amigos
# Nodo 34 y Nodo 45: amigos
# Nodo 34 y Nodo 46: amigos
# Nodo 34 y Nodo 47: enemigos
# Nodo 34 y Nodo 48: enemigos
# Nodo 34 y Nodo 49: enemigos
# Nodo 35 y Nodo 36: amigos
# Nodo 35 y Nodo 37: amigos
# Nodo 35 y Nodo 38: amigos
# Nodo 35 y Nodo 39: enemigos
# Nodo 35 y Nodo 40: amigos
# Nodo 35 y Nodo 41: enemigos
# Nodo 35 y Nodo 42: enemigos
# Nodo 35 y Nodo 43: enemigos
# Nodo 35 y Nodo 44: amigos
# Nodo 35 y Nodo 45: amigos
# Nodo 35 y Nodo 46: enemigos
# Nodo 35 y Nodo 47: enemigos
# Nodo 35 y Nodo 48: enemigos
# Nodo 35 y Nodo 49: enemigos
# Nodo 36 y Nodo 37: amigos
# Nodo 36 y Nodo 38: enemigos
# Nodo 36 y Nodo 39: amigos
# Nodo 36 y Nodo 40: amigos
# Nodo 36 y Nodo 41: enemigos
# Nodo 36 y Nodo 42: enemigos
# Nodo 36 y Nodo 43: enemigos
# Nodo 36 y Nodo 44: amigos
# Nodo 36 y Nodo 45: enemigos
# Nodo 36 y Nodo 46: amigos
# Nodo 36 y Nodo 47: amigos
# Nodo 36 y Nodo 48: enemigos
# Nodo 36 y Nodo 49: amigos
# Nodo 37 y Nodo 38: amigos
# Nodo 37 y Nodo 39: amigos
# Nodo 37 y Nodo 40: enemigos
# Nodo 37 y Nodo 41: enemigos
# Nodo 37 y Nodo 42: amigos
# Nodo 37 y Nodo 43: enemigos
# Nodo 37 y Nodo 44: amigos
# Nodo 37 y Nodo 45: amigos
# Nodo 37 y Nodo 46: amigos
# Nodo 37 y Nodo 47: enemigos
# Nodo 37 y Nodo 48: enemigos
# Nodo 37 y Nodo 49: enemigos
# Nodo 38 y Nodo 39: enemigos
# Nodo 38 y Nodo 40: enemigos
# Nodo 38 y Nodo 41: enemigos
# Nodo 38 y Nodo 42: amigos
# Nodo 38 y Nodo 43: enemigos
# Nodo 38 y Nodo 44: enemigos
# Nodo 38 y Nodo 45: amigos
# Nodo 38 y Nodo 46: enemigos
# Nodo 38 y Nodo 47: amigos
# Nodo 38 y Nodo 48: enemigos
# Nodo 38 y Nodo 49: enemigos
# Nodo 39 y Nodo 40: enemigos
# Nodo 39 y Nodo 41: enemigos
# Nodo 39 y Nodo 42: amigos
# Nodo 39 y Nodo 43: enemigos
# Nodo 39 y Nodo 44: amigos
# Nodo 39 y Nodo 45: enemigos
# Nodo 39 y Nodo 46: amigos
# Nodo 39 y Nodo 47: enemigos
# Nodo 39 y Nodo 48: amigos
# Nodo 39 y Nodo 49: amigos
# Nodo 40 y Nodo 41: enemigos
# Nodo 40 y Nodo 42: enemigos
# Nodo 40 y Nodo 43: amigos
# Nodo 40 y Nodo 44: enemigos
# Nodo 40 y Nodo 45: amigos
# Nodo 40 y Nodo 46: amigos
# Nodo 40 y Nodo 47: amigos
# Nodo 40 y Nodo 48: enemigos
# Nodo 40 y Nodo 49: amigos
# Nodo 41 y Nodo 42: enemigos
# Nodo 41 y Nodo 43: amigos
# Nodo 41 y Nodo 44: enemigos
# Nodo 41 y Nodo 45: enemigos
# Nodo 41 y Nodo 46: enemigos
# Nodo 41 y Nodo 47: enemigos
# Nodo 41 y Nodo 48: amigos
# Nodo 41 y Nodo 49: enemigos
# Nodo 42 y Nodo 43: enemigos
# Nodo 42 y Nodo 44: enemigos
# Nodo 42 y Nodo 45: enemigos
# Nodo 42 y Nodo 46: enemigos
# Nodo 42 y Nodo 47: amigos
# Nodo 42 y Nodo 48: amigos
# Nodo 42 y Nodo 49: enemigos
# Nodo 43 y Nodo 44: enemigos
# Nodo 43 y Nodo 45: amigos
# Nodo 43 y Nodo 46: enemigos
# Nodo 43 y Nodo 47: enemigos
# Nodo 43 y Nodo 48: enemigos
# Nodo 43 y Nodo 49: amigos
# Nodo 44 y Nodo 45: enemigos
# Nodo 44 y Nodo 46: amigos
# Nodo 44 y Nodo 47: enemigos
# Nodo 44 y Nodo 48: amigos
# Nodo 44 y Nodo 49: enemigos
# Nodo 45 y Nodo 46: amigos
# Nodo 45 y Nodo 47: enemigos
# Nodo 45 y Nodo 48: enemigos
# Nodo 45 y Nodo 49: enemigos
# Nodo 46 y Nodo 47: enemigos
# Nodo 46 y Nodo 48: amigos
# Nodo 46 y Nodo 49: amigos
# Nodo 47 y Nodo 48: amigos
# Nodo 47 y Nodo 49: enemigos
# Nodo 48 y Nodo 49: amigos
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# red_social.html
# La red se ha visualizado y guardado en 'red_social.html'

# %% [markdown]
# Se añade la función para eliminar los enlaces entre nodos enemigos, este recobra la topología vista en las redes de corrupción, donde únicamente están enlazados los nodos amigos.

# %%
import networkx as nx
import random
from pyvis.network import Network
import networkx as nx
import random
import json

def inicializar_red(num_nodos):
    """
    Crea una red completa y asigna relaciones aleatorias.
    """
    red = nx.Graph()
    red.add_nodes_from(range(num_nodos))
    for i in range(num_nodos):
        for j in range(i + 1, num_nodos):
            relacion = random.choice([1, -1])
            red.add_edge(i, j, relacion=relacion)
    return red

def obtener_relacion(red, nodo1, nodo2):
    return red[nodo1][nodo2]['relacion']

def es_triada_balanceada(red, nodo1, nodo2, nodo3):
    relacion12 = obtener_relacion(red, nodo1, nodo2)
    relacion13 = obtener_relacion(red, nodo1, nodo3)
    relacion23 = obtener_relacion(red, nodo2, nodo3)
    return relacion12 * relacion13 * relacion23 == 1

def encontrar_triada_no_balanceada(red):
    nodos = list(red.nodes())
    for i in range(len(nodos)):
        for j in range(i + 1, len(nodos)):
            for k in range(j + 1, len(nodos)):
                if red.has_edge(nodos[i], nodos[j]) and \
                   red.has_edge(nodos[i], nodos[k]) and \
                   red.has_edge(nodos[j], nodos[k]):
                    if not es_triada_balanceada(red, nodos[i], nodos[j], nodos[k]):
                        return nodos[i], nodos[j], nodos[k]
    return None

def aplicar_dinamica(red, nodo1, nodo2, nodo3):
    pares_nodos = [(nodo1, nodo2), (nodo1, nodo3), (nodo2, nodo3)]
    n1, n2 = random.choice(pares_nodos)
    otro_nodo = list(set([nodo1, nodo2, nodo3]) - set([n1, n2]))[0]
    nueva_relacion = obtener_relacion(red, n1, otro_nodo) * obtener_relacion(red, n2, otro_nodo)
    red[n1][n2]['relacion'] = nueva_relacion
    print(f"Se cambió la relación entre {n1} y {n2} a {'amigos' if nueva_relacion == 1 else 'enemigos'}.")

def simular_equilibrio(num_nodos, max_iteraciones=100):
    red = inicializar_red(num_nodos)
    iteracion = 0
    while iteracion < max_iteraciones:
        triada_no_balanceada = encontrar_triada_no_balanceada(red)
        if triada_no_balanceada:
            print(f"Iteración {iteracion}: Tríada no balanceada: {triada_no_balanceada}")
            aplicar_dinamica(red, *triada_no_balanceada)
        else:
            print(f"Equilibrio alcanzado en la iteración {iteracion}.")
            break
        iteracion += 1
    else:
        print(f"No se alcanzó el equilibrio tras {max_iteraciones} iteraciones.")
    return red

def eliminar_enemigos(red):
    """
    Elimina los enlaces entre nodos que son enemigos.

    Args:
        red (nx.Graph): La red.
    """
    edges_to_remove = []
    for u, v, data in red.edges(data=True):
        if data['relacion'] == -1:
            edges_to_remove.append((u, v))
    red.remove_edges_from(edges_to_remove)
    print("Se eliminaron los enlaces entre enemigos.")

def visualizar_red(red, filename="red_social.html"):
    """
    Visualiza la red utilizando pyvis con ajustes de física para mayor estabilidad.

    Args:
        red (nx.Graph): La red a visualizar.
        filename (str): El nombre del archivo HTML para guardar la visualización.
    """
    net = Network(notebook=True, height='100vh', width="100%", select_menu=True, filter_menu=True)

    # Configuración de la física para estabilizar la red
    net.barnes_hut() # Utiliza el algoritmo Barnes-Hut para mejor rendimiento en grafos grandes
    net.show_buttons() # Muestra los botones de física para control interactivo


    for node in red.nodes():
        net.add_node(node, label=str(node))

    for u, v, data in red.edges(data=True):
        color = "blue" if data['relacion'] == 1 else "red"
        weight = 1
        net.add_edge(u, v, color=color, weight=weight)

    net.show(filename, notebook=False)
    print(f"La red se ha visualizado y guardado en '{filename}'")

# Parámetros de la simulación
num_nodos = 20
red_equilibrada = simular_equilibrio(num_nodos)

# Imprimir las relaciones finales
print("\nRelaciones finales:")
for u, v, data in red_equilibrada.edges(data=True):
    relacion = "amigos" if data['relacion'] == 1 else "enemigos"
    print(f"Nodo {u} y Nodo {v}: {relacion}")

# Eliminar los enlaces de enemistad
eliminar_enemigos(red_equilibrada)

# Visualizar la red equilibrada
visualizar_red(red_equilibrada)
# Out:
# Iteración 0: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 1: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 2: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 3: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 4: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a enemigos.
# Iteración 5: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 1 y 7 a amigos.
# Iteración 6: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 1 y 8 a enemigos.
# Iteración 7: Tríada no balanceada: (0, 1, 14)
# Se cambió la relación entre 1 y 14 a enemigos.
# Iteración 8: Tríada no balanceada: (0, 1, 15)
# Se cambió la relación entre 1 y 15 a amigos.
# Iteración 9: Tríada no balanceada: (0, 1, 16)
# Se cambió la relación entre 0 y 16 a enemigos.
# Iteración 10: Tríada no balanceada: (0, 1, 17)
# Se cambió la relación entre 0 y 17 a amigos.
# Iteración 11: Tríada no balanceada: (0, 1, 19)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 12: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 13: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 14: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a enemigos.
# Iteración 15: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 5 a amigos.
# Iteración 16: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 17: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 18: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 19: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 20: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 21: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 22: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 23: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 24: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 25: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a amigos.
# Iteración 26: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 0 y 5 a enemigos.
# Iteración 27: Tríada no balanceada: (0, 1, 19)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 28: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 29: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 30: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a enemigos.
# Iteración 31: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a amigos.
# Iteración 32: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 6 a amigos.
# Iteración 33: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 1 y 7 a enemigos.
# Iteración 34: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 0 y 8 a amigos.
# Iteración 35: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 1 y 9 a amigos.
# Iteración 36: Tríada no balanceada: (0, 1, 10)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 37: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 38: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 39: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a enemigos.
# Iteración 40: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a enemigos.
# Iteración 41: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 42: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 43: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 44: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 45: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 1 y 3 a enemigos.
# Iteración 46: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 47: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 48: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 49: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 50: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 51: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 6 a enemigos.
# Iteración 52: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 7 a enemigos.
# Iteración 53: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 0 y 8 a enemigos.
# Iteración 54: Tríada no balanceada: (0, 1, 9)
# Se cambió la relación entre 0 y 9 a amigos.
# Iteración 55: Tríada no balanceada: (0, 1, 19)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 56: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 57: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 58: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 59: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 60: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 1 y 3 a amigos.
# Iteración 61: Tríada no balanceada: (0, 1, 19)
# Se cambió la relación entre 1 y 19 a amigos.
# Iteración 62: Tríada no balanceada: (0, 2, 3)
# Se cambió la relación entre 2 y 3 a enemigos.
# Iteración 63: Tríada no balanceada: (0, 2, 4)
# Se cambió la relación entre 2 y 4 a amigos.
# Iteración 64: Tríada no balanceada: (0, 2, 6)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 65: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 66: Tríada no balanceada: (0, 2, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 67: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 68: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 69: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 70: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 71: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 72: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 73: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 74: Tríada no balanceada: (0, 2, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 75: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 76: Tríada no balanceada: (0, 2, 3)
# Se cambió la relación entre 2 y 3 a amigos.
# Iteración 77: Tríada no balanceada: (0, 2, 4)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 78: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a enemigos.
# Iteración 79: Tríada no balanceada: (0, 2, 3)
# Se cambió la relación entre 0 y 3 a enemigos.
# Iteración 80: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 81: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 1 y 2 a amigos.
# Iteración 82: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 1 y 4 a amigos.
# Iteración 83: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a amigos.
# Iteración 84: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 6 a amigos.
# Iteración 85: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 86: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 87: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 88: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a enemigos.
# Iteración 89: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 0 y 7 a amigos.
# Iteración 90: Tríada no balanceada: (0, 1, 8)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 91: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 2 a amigos.
# Iteración 92: Tríada no balanceada: (0, 1, 3)
# Se cambió la relación entre 0 y 3 a amigos.
# Iteración 93: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 1 a enemigos.
# Iteración 94: Tríada no balanceada: (0, 1, 2)
# Se cambió la relación entre 0 y 1 a amigos.
# Iteración 95: Tríada no balanceada: (0, 1, 4)
# Se cambió la relación entre 0 y 4 a amigos.
# Iteración 96: Tríada no balanceada: (0, 1, 5)
# Se cambió la relación entre 1 y 5 a enemigos.
# Iteración 97: Tríada no balanceada: (0, 1, 6)
# Se cambió la relación entre 0 y 6 a enemigos.
# Iteración 98: Tríada no balanceada: (0, 1, 7)
# Se cambió la relación entre 1 y 7 a amigos.
# Iteración 99: Tríada no balanceada: (0, 2, 5)
# Se cambió la relación entre 0 y 2 a enemigos.
# No se alcanzó el equilibrio tras 100 iteraciones.
#
# Relaciones finales:
# Nodo 0 y Nodo 1: amigos
# Nodo 0 y Nodo 2: enemigos
# Nodo 0 y Nodo 3: amigos
# Nodo 0 y Nodo 4: amigos
# Nodo 0 y Nodo 5: enemigos
# Nodo 0 y Nodo 6: enemigos
# Nodo 0 y Nodo 7: amigos
# Nodo 0 y Nodo 8: enemigos
# Nodo 0 y Nodo 9: amigos
# Nodo 0 y Nodo 10: enemigos
# Nodo 0 y Nodo 11: enemigos
# Nodo 0 y Nodo 12: enemigos
# Nodo 0 y Nodo 13: amigos
# Nodo 0 y Nodo 14: enemigos
# Nodo 0 y Nodo 15: amigos
# Nodo 0 y Nodo 16: enemigos
# Nodo 0 y Nodo 17: amigos
# Nodo 0 y Nodo 18: enemigos
# Nodo 0 y Nodo 19: amigos
# Nodo 1 y Nodo 2: amigos
# Nodo 1 y Nodo 3: amigos
# Nodo 1 y Nodo 4: amigos
# Nodo 1 y Nodo 5: enemigos
# Nodo 1 y Nodo 6: enemigos
# Nodo 1 y Nodo 7: amigos
# Nodo 1 y Nodo 8: enemigos
# Nodo 1 y Nodo 9: amigos
# Nodo 1 y Nodo 10: enemigos
# Nodo 1 y Nodo 11: enemigos
# Nodo 1 y Nodo 12: enemigos
# Nodo 1 y Nodo 13: amigos
# Nodo 1 y Nodo 14: enemigos
# Nodo 1 y Nodo 15: amigos
# Nodo 1 y Nodo 16: enemigos
# Nodo 1 y Nodo 17: amigos
# Nodo 1 y Nodo 18: enemigos
# Nodo 1 y Nodo 19: amigos
# Nodo 2 y Nodo 3: amigos
# Nodo 2 y Nodo 4: amigos
# Nodo 2 y Nodo 5: amigos
# Nodo 2 y Nodo 6: enemigos
# Nodo 2 y Nodo 7: amigos
# Nodo 2 y Nodo 8: amigos
# Nodo 2 y Nodo 9: amigos
# Nodo 2 y Nodo 10: amigos
# Nodo 2 y Nodo 11: enemigos
# Nodo 2 y Nodo 12: enemigos
# Nodo 2 y Nodo 13: amigos
# Nodo 2 y Nodo 14: enemigos
# Nodo 2 y Nodo 15: enemigos
# Nodo 2 y Nodo 16: amigos
# Nodo 2 y Nodo 17: amigos
# Nodo 2 y Nodo 18: amigos
# Nodo 2 y Nodo 19: enemigos
# Nodo 3 y Nodo 4: enemigos
# Nodo 3 y Nodo 5: amigos
# Nodo 3 y Nodo 6: enemigos
# Nodo 3 y Nodo 7: enemigos
# Nodo 3 y Nodo 8: enemigos
# Nodo 3 y Nodo 9: amigos
# Nodo 3 y Nodo 10: enemigos
# Nodo 3 y Nodo 11: amigos
# Nodo 3 y Nodo 12: amigos
# Nodo 3 y Nodo 13: enemigos
# Nodo 3 y Nodo 14: enemigos
# Nodo 3 y Nodo 15: amigos
# Nodo 3 y Nodo 16: amigos
# Nodo 3 y Nodo 17: enemigos
# Nodo 3 y Nodo 18: enemigos
# Nodo 3 y Nodo 19: amigos
# Nodo 4 y Nodo 5: amigos
# Nodo 4 y Nodo 6: enemigos
# Nodo 4 y Nodo 7: amigos
# Nodo 4 y Nodo 8: amigos
# Nodo 4 y Nodo 9: enemigos
# Nodo 4 y Nodo 10: enemigos
# Nodo 4 y Nodo 11: amigos
# Nodo 4 y Nodo 12: amigos
# Nodo 4 y Nodo 13: amigos
# Nodo 4 y Nodo 14: enemigos
# Nodo 4 y Nodo 15: amigos
# Nodo 4 y Nodo 16: amigos
# Nodo 4 y Nodo 17: amigos
# Nodo 4 y Nodo 18: amigos
# Nodo 4 y Nodo 19: enemigos
# Nodo 5 y Nodo 6: amigos
# Nodo 5 y Nodo 7: amigos
# Nodo 5 y Nodo 8: amigos
# Nodo 5 y Nodo 9: amigos
# Nodo 5 y Nodo 10: amigos
# Nodo 5 y Nodo 11: amigos
# Nodo 5 y Nodo 12: enemigos
# Nodo 5 y Nodo 13: amigos
# Nodo 5 y Nodo 14: enemigos
# Nodo 5 y Nodo 15: amigos
# Nodo 5 y Nodo 16: amigos
# Nodo 5 y Nodo 17: enemigos
# Nodo 5 y Nodo 18: enemigos
# Nodo 5 y Nodo 19: amigos
# Nodo 6 y Nodo 7: amigos
# Nodo 6 y Nodo 8: enemigos
# Nodo 6 y Nodo 9: amigos
# Nodo 6 y Nodo 10: enemigos
# Nodo 6 y Nodo 11: amigos
# Nodo 6 y Nodo 12: amigos
# Nodo 6 y Nodo 13: amigos
# Nodo 6 y Nodo 14: enemigos
# Nodo 6 y Nodo 15: amigos
# Nodo 6 y Nodo 16: amigos
# Nodo 6 y Nodo 17: amigos
# Nodo 6 y Nodo 18: amigos
# Nodo 6 y Nodo 19: enemigos
# Nodo 7 y Nodo 8: amigos
# Nodo 7 y Nodo 9: amigos
# Nodo 7 y Nodo 10: enemigos
# Nodo 7 y Nodo 11: amigos
# Nodo 7 y Nodo 12: amigos
# Nodo 7 y Nodo 13: amigos
# Nodo 7 y Nodo 14: enemigos
# Nodo 7 y Nodo 15: enemigos
# Nodo 7 y Nodo 16: amigos
# Nodo 7 y Nodo 17: amigos
# Nodo 7 y Nodo 18: amigos
# Nodo 7 y Nodo 19: enemigos
# Nodo 8 y Nodo 9: enemigos
# Nodo 8 y Nodo 10: amigos
# Nodo 8 y Nodo 11: amigos
# Nodo 8 y Nodo 12: enemigos
# Nodo 8 y Nodo 13: amigos
# Nodo 8 y Nodo 14: enemigos
# Nodo 8 y Nodo 15: amigos
# Nodo 8 y Nodo 16: amigos
# Nodo 8 y Nodo 17: enemigos
# Nodo 8 y Nodo 18: enemigos
# Nodo 8 y Nodo 19: enemigos
# Nodo 9 y Nodo 10: amigos
# Nodo 9 y Nodo 11: amigos
# Nodo 9 y Nodo 12: amigos
# Nodo 9 y Nodo 13: amigos
# Nodo 9 y Nodo 14: amigos
# Nodo 9 y Nodo 15: amigos
# Nodo 9 y Nodo 16: amigos
# Nodo 9 y Nodo 17: enemigos
# Nodo 9 y Nodo 18: amigos
# Nodo 9 y Nodo 19: enemigos
# Nodo 10 y Nodo 11: amigos
# Nodo 10 y Nodo 12: enemigos
# Nodo 10 y Nodo 13: enemigos
# Nodo 10 y Nodo 14: enemigos
# Nodo 10 y Nodo 15: amigos
# Nodo 10 y Nodo 16: amigos
# Nodo 10 y Nodo 17: enemigos
# Nodo 10 y Nodo 18: amigos
# Nodo 10 y Nodo 19: enemigos
# Nodo 11 y Nodo 12: enemigos
# Nodo 11 y Nodo 13: amigos
# Nodo 11 y Nodo 14: amigos
# Nodo 11 y Nodo 15: amigos
# Nodo 11 y Nodo 16: enemigos
# Nodo 11 y Nodo 17: enemigos
# Nodo 11 y Nodo 18: enemigos
# Nodo 11 y Nodo 19: enemigos
# Nodo 12 y Nodo 13: amigos
# Nodo 12 y Nodo 14: amigos
# Nodo 12 y Nodo 15: enemigos
# Nodo 12 y Nodo 16: amigos
# Nodo 12 y Nodo 17: enemigos
# Nodo 12 y Nodo 18: amigos
# Nodo 12 y Nodo 19: enemigos
# Nodo 13 y Nodo 14: amigos
# Nodo 13 y Nodo 15: amigos
# Nodo 13 y Nodo 16: amigos
# Nodo 13 y Nodo 17: amigos
# Nodo 13 y Nodo 18: amigos
# Nodo 13 y Nodo 19: enemigos
# Nodo 14 y Nodo 15: enemigos
# Nodo 14 y Nodo 16: enemigos
# Nodo 14 y Nodo 17: amigos
# Nodo 14 y Nodo 18: enemigos
# Nodo 14 y Nodo 19: amigos
# Nodo 15 y Nodo 16: amigos
# Nodo 15 y Nodo 17: amigos
# Nodo 15 y Nodo 18: enemigos
# Nodo 15 y Nodo 19: enemigos
# Nodo 16 y Nodo 17: enemigos
# Nodo 16 y Nodo 18: enemigos
# Nodo 16 y Nodo 19: amigos
# Nodo 17 y Nodo 18: amigos
# Nodo 17 y Nodo 19: enemigos
# Nodo 18 y Nodo 19: amigos
# Se eliminaron los enlaces entre enemigos.
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# red_social.html
# La red se ha visualizado y guardado en 'red_social.html'
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.
